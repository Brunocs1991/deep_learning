# %%
#Carregando as bibliotecas
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import imdb
from keras.preprocessing.text import Tokenizer
from keras import models
from keras import layers
import warnings
warnings.filterwarnings('ignore')

# %%
# Resetar o gerador de numeros randômicos
np.random.seed(0)

# %%
# Definir o número de atributos (features)
number_of_features = 1000

# %%
# Carregar os dados (conjunto de dados de avaliacao de filmes)
(data_train, target_train), (data_test, target_test) = imdb.load_data(num_words=number_of_features)

# %%
# Converter o formato de dados para matriz de features
tokenizer = Tokenizer(num_words=number_of_features)
features_train = tokenizer.sequences_to_matrix(data_train, mode="binary")
features_test = tokenizer.sequences_to_matrix(data_test, mode="binary")

# %%
# Instancia a rede neural
network = models.Sequential()

# %%
# Adicionar a primeira camada com a função de ativacao Relu
network.add(layers.Dense(units=16, activation="relu", input_shape=(number_of_features,)))

# %%
# Adiciona a segunda camada com a função de ativação Relu
network.add(layers.Dense(units=16, activation="relu"))

# %%
# Adiciona a terceira camada coma função de ativação sigmoid
network.add(layers.Dense(units=1, activation="sigmoid"))

# %%
#Compilar a rede neural
network.compile(loss="binary_crossentropy", # Cross-entropy
                optimizer="rmsprop", # Root Mean Square Propagation
                metrics=["accuracy"]) # Acuracia como metrica de desempenho

# %%
#Treinar a rede neural
history = network.fit(features_train, # Atributos
                      target_train, # Classes
                      epochs=3, # Número de época
                      verbose=1, # Imprimir informações de cada época
                      batch_size=100, #Número de observações a cada mini-lote
                      validation_data=(features_test, target_test)) #Dados de teste
# Out:
# Epoch 1/30
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3027 - accuracy: 0.8730 - val_loss: 0.3276 - val_accuracy: 0.8594
# Epoch 2/30
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2916 - accuracy: 0.8797 - val_loss: 0.3277 - val_accuracy: 0.8602
# Epoch 3/30
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2784 - accuracy: 0.8837 - val_loss: 0.3323 - val_accuracy: 0.8587
# Epoch 4/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.2642 - accuracy: 0.8904 - val_loss: 0.3365 - val_accuracy: 0.8562
# Epoch 5/30
# 250/250 [==============================] - 1s 5ms/step - loss: 0.2484 - accuracy: 0.9001 - val_loss: 0.3449 - val_accuracy: 0.8552
# Epoch 6/30
# 250/250 [==============================] - 1s 5ms/step - loss: 0.2332 - accuracy: 0.9064 - val_loss: 0.3624 - val_accuracy: 0.8524
# Epoch 7/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.2178 - accuracy: 0.9137 - val_loss: 0.3826 - val_accuracy: 0.8514
# Epoch 8/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.2043 - accuracy: 0.9198 - val_loss: 0.3859 - val_accuracy: 0.8483
# Epoch 9/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.1915 - accuracy: 0.9256 - val_loss: 0.4010 - val_accuracy: 0.8484
# Epoch 10/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.1794 - accuracy: 0.9319 - val_loss: 0.4298 - val_accuracy: 0.8430
# Epoch 11/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.1670 - accuracy: 0.9372 - val_loss: 0.4589 - val_accuracy: 0.8424
# Epoch 12/30
# 250/250 [==============================] - 1s 3ms/step - loss: 0.1563 - accuracy: 0.9418 - val_loss: 0.5187 - val_accuracy: 0.8384
# Epoch 13/30
# 250/250 [==============================] - 1s 3ms/step - loss: 0.1458 - accuracy: 0.9472 - val_loss: 0.5160 - val_accuracy: 0.8396
# Epoch 14/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.1359 - accuracy: 0.9508 - val_loss: 0.5435 - val_accuracy: 0.8313
# Epoch 15/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.1261 - accuracy: 0.9555 - val_loss: 0.5920 - val_accuracy: 0.8262
# Epoch 16/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.1165 - accuracy: 0.9599 - val_loss: 0.6030 - val_accuracy: 0.8291
# Epoch 17/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.1078 - accuracy: 0.9628 - val_loss: 0.6499 - val_accuracy: 0.8287
# Epoch 18/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.0994 - accuracy: 0.9672 - val_loss: 0.6898 - val_accuracy: 0.8262
# Epoch 19/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.0918 - accuracy: 0.9709 - val_loss: 0.7460 - val_accuracy: 0.8297
# Epoch 20/30
# 250/250 [==============================] - 1s 5ms/step - loss: 0.0836 - accuracy: 0.9735 - val_loss: 0.7659 - val_accuracy: 0.8224
# Epoch 21/30
# 250/250 [==============================] - 1s 5ms/step - loss: 0.0767 - accuracy: 0.9755 - val_loss: 0.8234 - val_accuracy: 0.8206
# Epoch 22/30
# 250/250 [==============================] - 1s 5ms/step - loss: 0.0706 - accuracy: 0.9786 - val_loss: 0.8544 - val_accuracy: 0.8204
# Epoch 23/30
# 250/250 [==============================] - 1s 6ms/step - loss: 0.0635 - accuracy: 0.9811 - val_loss: 0.9177 - val_accuracy: 0.8199
# Epoch 24/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.0578 - accuracy: 0.9836 - val_loss: 0.9745 - val_accuracy: 0.8184
# Epoch 25/30
# 250/250 [==============================] - 1s 5ms/step - loss: 0.0522 - accuracy: 0.9856 - val_loss: 1.0830 - val_accuracy: 0.8203
# Epoch 26/30
# 250/250 [==============================] - 1s 5ms/step - loss: 0.0482 - accuracy: 0.9869 - val_loss: 1.0910 - val_accuracy: 0.8201
# Epoch 27/30
# 250/250 [==============================] - 1s 5ms/step - loss: 0.0435 - accuracy: 0.9892 - val_loss: 1.1368 - val_accuracy: 0.8172
# Epoch 28/30
# 250/250 [==============================] - 1s 5ms/step - loss: 0.0392 - accuracy: 0.9900 - val_loss: 1.1737 - val_accuracy: 0.8115
# Epoch 29/30
# 250/250 [==============================] - 1s 5ms/step - loss: 0.0349 - accuracy: 0.9911 - val_loss: 1.2212 - val_accuracy: 0.8155
# Epoch 30/30
# 250/250 [==============================] - 1s 6ms/step - loss: 0.0321 - accuracy: 0.9917 - val_loss: 1.2654 - val_accuracy: 0.8143

# %%
import pandas as pd

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()
