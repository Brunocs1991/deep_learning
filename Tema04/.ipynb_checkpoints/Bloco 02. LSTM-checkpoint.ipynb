# %% [markdown]
# # LSTM - Long Short-Term Memory

# %%
# Python ≥3.5 é necessário
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 é necessário
import sklearn
assert sklearn.__version__ >= "0.20"

try:
    # %tensorflow_version 2.x
except Exception:
    pass

# TensorFlow ≥2.0 é necessário
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

# imports comuns
import numpy as np
import os

# tornar os resultados reproduzíveis
np.random.seed(42)
tf.random.set_seed(42)

# Para apresentar figuras
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
def generate_time_series(batch_size, n_steps):
    freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0, 1, n_steps)
    series = 0.5 * np.sin((time - offsets1) * (freq1 * 10 + 10))  #   onda 1
    series += 0.2 * np.sin((time - offsets2) * (freq2 * 20 + 20)) # + onada 2
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5)   # + ruído
    return series[..., np.newaxis].astype(np.float32)

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 10)
X_train = series[:7000, :n_steps]
X_valid = series[7000:9000, :n_steps]
X_test = series[9000:, :n_steps]
Y = np.empty((10000, n_steps, 10))
for step_ahead in range(1, 10 + 1):
    Y[..., step_ahead - 1] = series[..., step_ahead:step_ahead + n_steps, 0]
Y_train = Y[:7000]
Y_valid = Y[7000:9000]
Y_test = Y[9000:]

# %%
X_train.shape, Y_train.shape, X_valid.shape, Y_valid.shape
# Out:
# ((7000, 50, 1), (7000, 50, 10), (2000, 50, 1), (2000, 50, 10))

# %%
def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.LSTM(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.LSTM(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 14s 51ms/step - loss: 0.0758 - last_time_step_mse: 0.0623 - val_loss: 0.0542 - val_last_time_step_mse: 0.0360
# Epoch 2/20
# 219/219 [==============================] - 9s 39ms/step - loss: 0.0480 - last_time_step_mse: 0.0304 - val_loss: 0.0421 - val_last_time_step_mse: 0.0221
# Epoch 3/20
# 219/219 [==============================] - 10s 47ms/step - loss: 0.0378 - last_time_step_mse: 0.0186 - val_loss: 0.0350 - val_last_time_step_mse: 0.0155
# Epoch 4/20
# 219/219 [==============================] - 9s 41ms/step - loss: 0.0332 - last_time_step_mse: 0.0142 - val_loss: 0.0318 - val_last_time_step_mse: 0.0133
# Epoch 5/20
# 219/219 [==============================] - 10s 44ms/step - loss: 0.0311 - last_time_step_mse: 0.0130 - val_loss: 0.0299 - val_last_time_step_mse: 0.0116
# Epoch 6/20
# 219/219 [==============================] - 11s 52ms/step - loss: 0.0295 - last_time_step_mse: 0.0116 - val_loss: 0.0288 - val_last_time_step_mse: 0.0115
# Epoch 7/20
# 219/219 [==============================] - 9s 42ms/step - loss: 0.0285 - last_time_step_mse: 0.0109 - val_loss: 0.0287 - val_last_time_step_mse: 0.0132
# Epoch 8/20
# 219/219 [==============================] - 11s 51ms/step - loss: 0.0276 - last_time_step_mse: 0.0102 - val_loss: 0.0270 - val_last_time_step_mse: 0.0097
# Epoch 9/20
# 219/219 [==============================] - 11s 50ms/step - loss: 0.0273 - last_time_step_mse: 0.0102 - val_loss: 0.0269 - val_last_time_step_mse: 0.0103
# Epoch 10/20
# 219/219 [==============================] - 9s 42ms/step - loss: 0.0266 - last_time_step_mse: 0.0097 - val_loss: 0.0261 - val_last_time_step_mse: 0.0094
# Epoch 11/20
# 219/219 [==============================] - 11s 51ms/step - loss: 0.0262 - last_time_step_mse: 0.0096 - val_loss: 0.0257 - val_last_time_step_mse: 0.0092
# Epoch 12/20
# 219/219 [==============================] - 11s 49ms/step - loss: 0.0259 - last_time_step_mse: 0.0095 - val_loss: 0.0255 - val_last_time_step_mse: 0.0091
# Epoch 13/20
# 219/219 [==============================] - 10s 44ms/step - loss: 0.0255 - last_time_step_mse: 0.0091 - val_loss: 0.0253 - val_last_time_step_mse: 0.0091
# Epoch 14/20
# 219/219 [==============================] - 11s 52ms/step - loss: 0.0253 - last_time_step_mse: 0.0092 - val_loss: 0.0250 - val_last_time_step_mse: 0.0086
# Epoch 15/20
# 219/219 [==============================] - 10s 48ms/step - loss: 0.0250 - last_time_step_mse: 0.0089 - val_loss: 0.0247 - val_last_time_step_mse: 0.0086
# Epoch 16/20
# 219/219 [==============================] - 10s 45ms/step - loss: 0.0248 - last_time_step_mse: 0.0090 - val_loss: 0.0248 - val_last_time_step_mse: 0.0091
# Epoch 17/20
# 219/219 [==============================] - 11s 52ms/step - loss: 0.0245 - last_time_step_mse: 0.0088 - val_loss: 0.0248 - val_last_time_step_mse: 0.0097
# Epoch 18/20
# 219/219 [==============================] - 10s 48ms/step - loss: 0.0242 - last_time_step_mse: 0.0087 - val_loss: 0.0243 - val_last_time_step_mse: 0.0089
# Epoch 19/20
# 219/219 [==============================] - 10s 45ms/step - loss: 0.0240 - last_time_step_mse: 0.0085 - val_loss: 0.0239 - val_last_time_step_mse: 0.0092
# Epoch 20/20
# 219/219 [==============================] - 11s 52ms/step - loss: 0.0237 - last_time_step_mse: 0.0084 - val_loss: 0.0235 - val_last_time_step_mse: 0.0081

# %%
model.evaluate(X_valid, Y_valid)
# Out:
# 63/63 [==============================] - 1s 13ms/step - loss: 0.0235 - last_time_step_mse: 0.0081
# [0.023543167859315872, 0.008083028718829155]

# %%
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.axis([1, 20, 0, 0.05])
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, 50:, :]
Y_pred = model.predict(X_new)[:, -1][..., np.newaxis]
# Out:
# 1/1 [==============================] - 1s 682ms/step

# %%
def plot_multiple_forecasts(X, Y, Y_pred):
    n_steps = X.shape[1]
    ahead = Y.shape[1]
    plot_series(X[0, :, 0])
    plt.plot(np.arange(n_steps, n_steps + ahead), Y[0, :, 0], "ro-", label="Actual")
    plt.plot(np.arange(n_steps, n_steps + ahead), Y_pred[0, :, 0], "bx-", label="Forecast", markersize=10)
    plt.axis([0, n_steps + ahead, -1, 1])
    plt.legend(fontsize=14)
    
def plot_series(series, y=None, y_pred=None, x_label="$t$", y_label="$x(t)$"):
    plt.plot(series, ".-")
    if y is not None:
        plt.plot(n_steps, y, "bx", markersize=10)
    if y_pred is not None:
        plt.plot(n_steps, y_pred, "ro")
    plt.grid(True)
    if x_label:
        plt.xlabel(x_label, fontsize=16)
    if y_label:
        plt.ylabel(y_label, fontsize=16, rotation=0)
    plt.hlines(0, 0, 100, linewidth=1)
    plt.axis([0, n_steps + 1, -1, 1])

plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# # GRUs

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.GRU(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 14s 47ms/step - loss: 0.0723 - last_time_step_mse: 0.0634 - val_loss: 0.0534 - val_last_time_step_mse: 0.0433
# Epoch 2/20
# 219/219 [==============================] - 10s 47ms/step - loss: 0.0481 - last_time_step_mse: 0.0370 - val_loss: 0.0445 - val_last_time_step_mse: 0.0322
# Epoch 3/20
# 219/219 [==============================] - 9s 41ms/step - loss: 0.0416 - last_time_step_mse: 0.0292 - val_loss: 0.0390 - val_last_time_step_mse: 0.0256
# Epoch 4/20
# 219/219 [==============================] - 11s 49ms/step - loss: 0.0377 - last_time_step_mse: 0.0243 - val_loss: 0.0362 - val_last_time_step_mse: 0.0213
# Epoch 5/20
# 219/219 [==============================] - 10s 46ms/step - loss: 0.0350 - last_time_step_mse: 0.0218 - val_loss: 0.0338 - val_last_time_step_mse: 0.0206
# Epoch 6/20
# 219/219 [==============================] - 11s 50ms/step - loss: 0.0326 - last_time_step_mse: 0.0194 - val_loss: 0.0320 - val_last_time_step_mse: 0.0190
# Epoch 7/20
# 219/219 [==============================] - 12s 55ms/step - loss: 0.0307 - last_time_step_mse: 0.0174 - val_loss: 0.0304 - val_last_time_step_mse: 0.0181
# Epoch 8/20
# 219/219 [==============================] - 11s 52ms/step - loss: 0.0291 - last_time_step_mse: 0.0154 - val_loss: 0.0281 - val_last_time_step_mse: 0.0142
# Epoch 9/20
# 219/219 [==============================] - 10s 47ms/step - loss: 0.0279 - last_time_step_mse: 0.0140 - val_loss: 0.0272 - val_last_time_step_mse: 0.0129
# Epoch 10/20
# 219/219 [==============================] - 12s 54ms/step - loss: 0.0271 - last_time_step_mse: 0.0132 - val_loss: 0.0268 - val_last_time_step_mse: 0.0134
# Epoch 11/20
# 219/219 [==============================] - 12s 56ms/step - loss: 0.0264 - last_time_step_mse: 0.0124 - val_loss: 0.0262 - val_last_time_step_mse: 0.0123
# Epoch 12/20
# 219/219 [==============================] - 10s 47ms/step - loss: 0.0259 - last_time_step_mse: 0.0119 - val_loss: 0.0255 - val_last_time_step_mse: 0.0114
# Epoch 13/20
# 219/219 [==============================] - 11s 51ms/step - loss: 0.0254 - last_time_step_mse: 0.0113 - val_loss: 0.0251 - val_last_time_step_mse: 0.0111
# Epoch 14/20
# 219/219 [==============================] - 12s 56ms/step - loss: 0.0250 - last_time_step_mse: 0.0110 - val_loss: 0.0249 - val_last_time_step_mse: 0.0109
# Epoch 15/20
# 219/219 [==============================] - 11s 52ms/step - loss: 0.0247 - last_time_step_mse: 0.0107 - val_loss: 0.0244 - val_last_time_step_mse: 0.0103
# Epoch 16/20
# 219/219 [==============================] - 12s 55ms/step - loss: 0.0243 - last_time_step_mse: 0.0104 - val_loss: 0.0244 - val_last_time_step_mse: 0.0104
# Epoch 17/20
# 219/219 [==============================] - 12s 54ms/step - loss: 0.0241 - last_time_step_mse: 0.0103 - val_loss: 0.0243 - val_last_time_step_mse: 0.0104
# Epoch 18/20
# 219/219 [==============================] - 12s 56ms/step - loss: 0.0238 - last_time_step_mse: 0.0100 - val_loss: 0.0235 - val_last_time_step_mse: 0.0095
# Epoch 19/20
# 219/219 [==============================] - 11s 49ms/step - loss: 0.0235 - last_time_step_mse: 0.0097 - val_loss: 0.0233 - val_last_time_step_mse: 0.0093
# Epoch 20/20
# 219/219 [==============================] - 11s 49ms/step - loss: 0.0233 - last_time_step_mse: 0.0095 - val_loss: 0.0231 - val_last_time_step_mse: 0.0093

# %%
model.evaluate(X_valid, Y_valid)
# Out:
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0231 - last_time_step_mse: 0.0093
# [0.023139966651797295, 0.009333197958767414]

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, 50:, :]
Y_pred = model.predict(X_new)[:, -1][..., np.newaxis]
# Out:
# 1/1 [==============================] - 1s 694ms/step

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()
