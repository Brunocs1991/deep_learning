# %% [markdown]
# # Redes Neurais Recorrentes

# %%
# Python ≥3.5 é necessário
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 é necessário
import sklearn
assert sklearn.__version__ >= "0.20"

try:
    # %tensorflow_version 2.x
except Exception:
    pass

# TensorFlow ≥2.0 é necessário
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

# imports comuns
import numpy as np
import os

# tornar os resultados reproduzíveis
np.random.seed(42)
tf.random.set_seed(42)

# Para apresentar figuras
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %% [markdown]
# ### Geração de um conjunto de dados

# %%
def generate_time_series(batch_size, n_steps):
    freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0, 1, n_steps)
    series = 0.5 * np.sin((time - offsets1) * (freq1 * 10 + 10))  #   onda 1
    series += 0.2 * np.sin((time - offsets2) * (freq2 * 20 + 20)) # + onda 2
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5)   # + ruído
    return series[..., np.newaxis].astype(np.float32)

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 1)
X_train, y_train = series[:7000, :n_steps], series[:7000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_test, y_test = series[9000:, :n_steps], series[9000:, -1]

# %%
X_train.shape, y_train.shape
# Out:
# ((7000, 50, 1), (7000, 1))

# %%
def plot_series(series, y=None, y_pred=None, x_label="$t$", y_label="$x(t)$"):
    plt.plot(series, ".-")
    if y is not None:
        plt.plot(n_steps, y, "bx", markersize=10)
    if y_pred is not None:
        plt.plot(n_steps, y_pred, "ro")
    plt.grid(True)
    if x_label:
        plt.xlabel(x_label, fontsize=16)
    if y_label:
        plt.ylabel(y_label, fontsize=16, rotation=0)
    plt.hlines(0, 0, 100, linewidth=1)
    plt.axis([0, n_steps + 1, -1, 1])

fig, axes = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(12, 4))
for col in range(3):
    plt.sca(axes[col])
    plot_series(X_valid[col, :, 0], y_valid[col, 0],
                y_label=("$x(t)$" if col==0 else None))
plt.show()

# %% [markdown]
# ## Construção de uma rede neural simples

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(1, input_shape=[None, 1])
])

optimizer = keras.optimizers.Adam(lr=0.005)
model.compile(loss="mse", optimizer=optimizer)
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/20
# 219/219 [==============================] - 3s 10ms/step - loss: 0.0158 - val_loss: 0.0125
# Epoch 2/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0122 - val_loss: 0.0113
# Epoch 3/20
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0117 - val_loss: 0.0110
# Epoch 4/20
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0115 - val_loss: 0.0110
# Epoch 5/20
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 6/20
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 7/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 8/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 9/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 10/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 11/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 12/20
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 13/20
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 14/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 15/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 16/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 17/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 18/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 19/20
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 20/20
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0114 - val_loss: 0.0109

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0109
# 0.010869404301047325

# %%
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.axis([1, 20, 0, 0.05])
    plt.legend(fontsize=14)
    plt.xlabel("Epocas")
    plt.ylabel("Perda")
    plt.grid(True)

plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %% [markdown]
# ## Construção de uma rede neural profunda

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.SimpleRNN(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 10s 36ms/step - loss: 0.0272 - val_loss: 0.0042
# Epoch 2/20
# 219/219 [==============================] - 5s 24ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 3/20
# 219/219 [==============================] - 7s 32ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 4/20
# 219/219 [==============================] - 7s 30ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 5/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 6/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 7/20
# 219/219 [==============================] - 5s 25ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 8/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 9/20
# 219/219 [==============================] - 6s 30ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 10/20
# 219/219 [==============================] - 6s 28ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 11/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 12/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 13/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 14/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 15/20
# 219/219 [==============================] - 6s 26ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 16/20
# 219/219 [==============================] - 8s 38ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 17/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 18/20
# 219/219 [==============================] - 9s 40ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 19/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 20/20
# 219/219 [==============================] - 9s 40ms/step - loss: 0.0028 - val_loss: 0.0028

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 1s 12ms/step - loss: 0.0028
# 0.0027831236366182566

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()
# Out:
# 63/63 [==============================] - 1s 6ms/step

# %% [markdown]
# ## Previsão de valores

# %%
np.random.seed(43) 

series = generate_time_series(1, n_steps + 10)
X_new, Y_new = series[:, :n_steps], series[:, n_steps:]
X = X_new
for step_ahead in range(10):
    y_pred_one = model.predict(X[:, step_ahead:])[:, np.newaxis, :]
    X = np.concatenate([X, y_pred_one], axis=1)

Y_pred = X[:, n_steps:]
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
Y_pred.shape
# Out:
# (1, 10, 1)

# %%
def plot_multiple_forecasts(X, Y, Y_pred):
    n_steps = X.shape[1]
    ahead = Y.shape[1]
    plot_series(X[0, :, 0])
    plt.plot(np.arange(n_steps, n_steps + ahead), Y[0, :, 0], "ro-", label="Actual")
    plt.plot(np.arange(n_steps, n_steps + ahead), Y_pred[0, :, 0], "bx-", label="Forecast", markersize=10)
    plt.axis([0, n_steps + ahead, -1, 1])
    plt.legend(fontsize=14)

plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# **Agora vamos usar este modelo para prever os próximos 10 valores. Primeiro nós regeramos as sequências, com dez passos a mais.**

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 10)
X_train, Y_train = series[:7000, :n_steps], series[:7000, -10:, 0]
X_valid, Y_valid = series[7000:9000, :n_steps], series[7000:9000, -10:, 0]
X_test, Y_test = series[9000:, :n_steps], series[9000:, -10:, 0]

# %% [markdown]
# Agora, prevemos os próximos 10 valores um por um.

# %%
X = X_valid
for step_ahead in range(10):
    y_pred_one = model.predict(X)[:, np.newaxis, :]
    X = np.concatenate([X, y_pred_one], axis=1)

Y_pred = X[:, n_steps:, 0]
# Out:
# 63/63 [==============================] - 0s 6ms/step
# 63/63 [==============================] - 1s 6ms/step
# 63/63 [==============================] - 0s 6ms/step
# 63/63 [==============================] - 0s 7ms/step
# 63/63 [==============================] - 0s 7ms/step
# 63/63 [==============================] - 0s 7ms/step
# 63/63 [==============================] - 1s 8ms/step
# 63/63 [==============================] - 1s 9ms/step
# 63/63 [==============================] - 1s 9ms/step
# 63/63 [==============================] - 1s 9ms/step

# %%
Y_pred.shape
# Out:
# (2000, 10)

# %%
np.mean(keras.metrics.mean_squared_error(Y_valid, Y_pred))
# Out:
# 0.026691101

# %% [markdown]
# Vamos comparar o desempenho com alguns baselines: previsão naive e modelo linear simples.

# %%
Y_naive_pred = Y_valid[:, -1:]
np.mean(keras.metrics.mean_squared_error(Y_valid, Y_naive_pred))
# Out:
# 0.22278848

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[50, 1]),
    keras.layers.Dense(10)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.1280 - val_loss: 0.0602
# Epoch 2/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0486 - val_loss: 0.0404
# Epoch 3/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0365 - val_loss: 0.0333
# Epoch 4/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0316 - val_loss: 0.0297
# Epoch 5/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0287 - val_loss: 0.0273
# Epoch 6/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0266 - val_loss: 0.0258
# Epoch 7/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0251 - val_loss: 0.0244
# Epoch 8/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0240 - val_loss: 0.0233
# Epoch 9/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0231 - val_loss: 0.0226
# Epoch 10/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0224 - val_loss: 0.0219
# Epoch 11/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0218 - val_loss: 0.0214
# Epoch 12/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0212 - val_loss: 0.0210
# Epoch 13/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0208 - val_loss: 0.0205
# Epoch 14/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0204 - val_loss: 0.0205
# Epoch 15/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0201 - val_loss: 0.0200
# Epoch 16/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0198 - val_loss: 0.0197
# Epoch 17/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0195 - val_loss: 0.0193
# Epoch 18/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0192 - val_loss: 0.0190
# Epoch 19/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0189 - val_loss: 0.0188
# Epoch 20/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0187 - val_loss: 0.0186

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2062
# 0.20618502795696259

# %% [markdown]
# **Agora vamos criar uma RNN que prevê 10 valores em um único passo.**

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(10)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 5s 18ms/step - loss: 0.0480 - val_loss: 0.0256
# Epoch 2/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0225 - val_loss: 0.0176
# Epoch 3/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0177 - val_loss: 0.0164
# Epoch 4/20
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0149 - val_loss: 0.0134
# Epoch 5/20
# 219/219 [==============================] - 4s 19ms/step - loss: 0.0139 - val_loss: 0.0129
# Epoch 6/20
# 219/219 [==============================] - 5s 25ms/step - loss: 0.0126 - val_loss: 0.0117
# Epoch 7/20
# 219/219 [==============================] - 4s 19ms/step - loss: 0.0119 - val_loss: 0.0109
# Epoch 8/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 9/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0104 - val_loss: 0.0109
# Epoch 10/20
# 219/219 [==============================] - 5s 24ms/step - loss: 0.0112 - val_loss: 0.0100
# Epoch 11/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0102 - val_loss: 0.0103
# Epoch 12/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0103 - val_loss: 0.0092
# Epoch 13/20
# 219/219 [==============================] - 5s 24ms/step - loss: 0.0099 - val_loss: 0.0089
# Epoch 14/20
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0097 - val_loss: 0.0089
# Epoch 15/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0092 - val_loss: 0.0090
# Epoch 16/20
# 219/219 [==============================] - 4s 19ms/step - loss: 0.0097 - val_loss: 0.0102
# Epoch 17/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0094 - val_loss: 0.0153
# Epoch 18/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0098 - val_loss: 0.0087
# Epoch 19/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0092 - val_loss: 0.0083
# Epoch 20/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0092 - val_loss: 0.0088

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, -10:, :]
Y_pred = model.predict(X_new)[..., np.newaxis]
# Out:
# 1/1 [==============================] - 0s 415ms/step

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# Agora vamos criar uma RNN que prevê os próximos 10 valores a cada passo de tempo, ou seja, ao invés de apenas prever os passos de 50 a 59 baseado nos passos 40 a 49, a RNN irá prever os passos de 1 a 10 no tempo 0, os passos de 2 a 11 no tempo 1, e assim sucessivamente, até prever os passos 50 a 59 no último intervalo de tempo.

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 10)
X_train = series[:7000, :n_steps]
X_valid = series[7000:9000, :n_steps]
X_test = series[9000:, :n_steps]
Y = np.empty((10000, n_steps, 10))
for step_ahead in range(1, 10 + 1):
    Y[..., step_ahead - 1] = series[..., step_ahead:step_ahead + n_steps, 0]
Y_train = Y[:7000]
Y_valid = Y[7000:9000]
Y_test = Y[9000:]

# %%
X_train.shape, Y_train.shape
# Out:
# ((7000, 50, 1), (7000, 50, 10))

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

model.compile(loss="mse", optimizer=keras.optimizers.Adam(lr=0.01), metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/20
# 219/219 [==============================] - 6s 20ms/step - loss: 0.0647 - last_time_step_mse: 0.0558 - val_loss: 0.0489 - val_last_time_step_mse: 0.0372
# Epoch 2/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0439 - last_time_step_mse: 0.0307 - val_loss: 0.0393 - val_last_time_step_mse: 0.0244
# Epoch 3/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0374 - last_time_step_mse: 0.0218 - val_loss: 0.0368 - val_last_time_step_mse: 0.0224
# Epoch 4/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0352 - last_time_step_mse: 0.0193 - val_loss: 0.0335 - val_last_time_step_mse: 0.0173
# Epoch 5/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0337 - last_time_step_mse: 0.0180 - val_loss: 0.0327 - val_last_time_step_mse: 0.0167
# Epoch 6/20
# 219/219 [==============================] - 4s 19ms/step - loss: 0.0328 - last_time_step_mse: 0.0172 - val_loss: 0.0320 - val_last_time_step_mse: 0.0155
# Epoch 7/20
# 219/219 [==============================] - 6s 27ms/step - loss: 0.0323 - last_time_step_mse: 0.0169 - val_loss: 0.0312 - val_last_time_step_mse: 0.0153
# Epoch 8/20
# 219/219 [==============================] - 4s 19ms/step - loss: 0.0315 - last_time_step_mse: 0.0159 - val_loss: 0.0305 - val_last_time_step_mse: 0.0142
# Epoch 9/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0309 - last_time_step_mse: 0.0154 - val_loss: 0.0305 - val_last_time_step_mse: 0.0145
# Epoch 10/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0305 - last_time_step_mse: 0.0151 - val_loss: 0.0304 - val_last_time_step_mse: 0.0153
# Epoch 11/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0302 - last_time_step_mse: 0.0149 - val_loss: 0.0293 - val_last_time_step_mse: 0.0132
# Epoch 12/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0297 - last_time_step_mse: 0.0145 - val_loss: 0.0294 - val_last_time_step_mse: 0.0145
# Epoch 13/20
# 219/219 [==============================] - 4s 19ms/step - loss: 0.0291 - last_time_step_mse: 0.0138 - val_loss: 0.0286 - val_last_time_step_mse: 0.0134
# Epoch 14/20
# 219/219 [==============================] - 5s 25ms/step - loss: 0.0288 - last_time_step_mse: 0.0136 - val_loss: 0.0283 - val_last_time_step_mse: 0.0134
# Epoch 15/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0284 - last_time_step_mse: 0.0132 - val_loss: 0.0277 - val_last_time_step_mse: 0.0123
# Epoch 16/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0280 - last_time_step_mse: 0.0130 - val_loss: 0.0274 - val_last_time_step_mse: 0.0128
# Epoch 17/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0274 - last_time_step_mse: 0.0125 - val_loss: 0.0270 - val_last_time_step_mse: 0.0117
# Epoch 18/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0270 - last_time_step_mse: 0.0121 - val_loss: 0.0265 - val_last_time_step_mse: 0.0114
# Epoch 19/20
# 219/219 [==============================] - 4s 19ms/step - loss: 0.0267 - last_time_step_mse: 0.0119 - val_loss: 0.0262 - val_last_time_step_mse: 0.0113
# Epoch 20/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0263 - last_time_step_mse: 0.0116 - val_loss: 0.0259 - val_last_time_step_mse: 0.0111

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, 50:, :]
Y_pred = model.predict(X_new)[:, -1][..., np.newaxis]
# Out:
# 1/1 [==============================] - 0s 350ms/step

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()
